# %%
from PIL import Image

# Load ảnh
img = Image.open('/home/ubuntu/vnet/Optimize-Rouitng-and-Placing-on-VLSI/Thesis/DREAMPlace/install/results/adaptec1/plot/iter0000.png')

# Flip vertical (lật trên-dưới)
img_rotated = img.transpose(Image.FLIP_TOP_BOTTOM)

# Lưu ảnh
img_rotated.save('/home/ubuntu/vnet/Optimize-Rouitng-and-Placing-on-VLSI/Thesis/DREAMPlace/install/results/adaptec1/plot/iter0000.png')

print("✓ Ảnh đã rotate xong!")
# Out:
# ✓ Ảnh đã rotate xong!
